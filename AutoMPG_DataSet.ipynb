# %%
#import libary for use method
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
colum_names=['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin','carname']

# %%
df =pd.read_csv('auto-mpg.csv',header = None,sep="\s+",names=colum_names)
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0        8.0         307.0       130.0  3504.0          12.0
# 1  15.0        8.0         350.0       165.0  3693.0          11.5
# 2  18.0        8.0         318.0       150.0  3436.0          11.0
# 3  16.0        8.0         304.0       150.0  3433.0          12.0
# 4  17.0        8.0         302.0       140.0  3449.0          10.5
#
#    model year  origin                    carname
# 0        70.0     1.0  chevrolet chevelle malibu
# 1        70.0     1.0          buick skylark 320
# 2        70.0     1.0         plymouth satellite
# 3        70.0     1.0              amc rebel sst
# 4        70.0     1.0                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     406 non-null    float64
#  2   displacement  406 non-null    float64
#  3   horsepower    400 non-null    float64
#  4   weight        406 non-null    float64
#  5   acceleration  406 non-null    float64
#  6   model year    406 non-null    float64
#  7   origin        406 non-null    float64
#  8   carname       406 non-null    object
# dtypes: float64(8), object(1)
# memory usage: 28.7+ KB

# %%
df.shape
# Out:
# (406, 9)

# %%
df.describe().transpose()
# Out:
#               count         mean         std     min      25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.50    23.0
# cylinders     406.0     5.475369    1.712160     3.0     4.00     4.0
# displacement  406.0   194.779557  104.922458    68.0   105.00   151.0
# horsepower    400.0   105.082500   38.768779    46.0    75.75    95.0
# weight        406.0  2979.413793  847.004328  1613.0  2226.50  2822.5
# acceleration  406.0    15.519704    2.803359     8.0    13.70    15.5
# model year    406.0    75.921182    3.748737    70.0    73.00    76.0
# origin        406.0     1.568966    0.797479     1.0     1.00     1.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   302.000   455.0
# horsepower     130.000   230.0
# weight        3618.250  5140.0
# acceleration    17.175    24.8
# model year      79.000    82.0
# origin           2.000     3.0

# %%
#checking for missing values in data
df.isnull().sum()
# Out:
# mpg             8
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# carname         0
# dtype: int64

# %%
df.fillna(df[["mpg"]].mean(),inplace=True)

df.fillna(df[["horsepower"]].mean(),inplace=True)

# %%
# Again checking for missing values in data
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# carname         0
# dtype: int64

# %%
#Check Out Correlation
f,ax = plt.subplots(figsize = (8, 8))
sns.heatmap(df.corr(), annot = True, linewidths = 0.1, fmt = '.1f', ax = ax, square = True)

# %%
df["carname"] = df["carname"].str.title()
df["company"] = df["carname"].str.split(" ").str[0]
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0        8.0         307.0       130.0  3504.0          12.0
# 1  15.0        8.0         350.0       165.0  3693.0          11.5
# 2  18.0        8.0         318.0       150.0  3436.0          11.0
# 3  16.0        8.0         304.0       150.0  3433.0          12.0
# 4  17.0        8.0         302.0       140.0  3449.0          10.5
#
#    model year  origin                    carname    company
# 0        70.0     1.0  Chevrolet Chevelle Malibu  Chevrolet
# 1        70.0     1.0          Buick Skylark 320      Buick
# 2        70.0     1.0         Plymouth Satellite   Plymouth
# 3        70.0     1.0              Amc Rebel Sst        Amc
# 4        70.0     1.0                Ford Torino       Ford

# %%
df["company"].value_counts()
# Out:
# Ford             53
# Chevrolet        44
# Plymouth         32
# Amc              29
# Dodge            28
# Toyota           25
# Datsun           23
# Buick            17
# Volkswagen       16
# Pontiac          16
# Honda            13
# Mercury          11
# Mazda            10
# Oldsmobile       10
# Peugeot           8
# Fiat              8
# Audi              7
# Chrysler          6
# Volvo             6
# Vw                6
# Saab              5
# Renault           5
# Subaru            4
# Opel              4
# Chevy             3
# Maxda             2
# Cadillac          2
# Mercedes-Benz     2
# Bmw               2
# Chevroelt         1
# Triumph           1
# Nissan            1
# Mercedes          1
# Vokswagen         1
# Hi                1
# Citroen           1
# Capri             1
# Toyouta           1
# Name: company, dtype: int64

# %%
sns.distplot(df["mpg"])
plt.xlabel("MPG")
plt.ylabel("Number of Cars")
plt.title("Distribution of MPG")
plt.show()

# %%
plt.boxplot(df["mpg"])
plt.xlabel("MPG")
plt.title("Box Plot of MPG")
plt.show()

# %%
df['cylinders'].hist()
plt.title("cylinders")
# Out:
# Text(0.5, 1.0, 'cylinders')

# %%
df['displacement'].hist()
plt.title("displacement")
# Out:
# Text(0.5, 1.0, 'displacement')

# %%
df['horsepower'].hist()
plt.title('horsepower')
# Out:
# Text(0.5, 1.0, 'horsepower')

# %%
df['weight'].hist()
plt.title('weight')
# Out:
# Text(0.5, 1.0, 'weight')

# %%
df['acceleration'].hist()
plt.title('acceleration')
# Out:
# Text(0.5, 1.0, 'acceleration')

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df ,kind="reg",size=2.5)
plt.show()

# %%
#lets check for outliers using z score
df=pd.DataFrame(df.drop(['carname','company'],axis=1))
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df))
df_new=df.loc[(abs(z)<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
#from below output it is clear that some outliers were there and now these are removed
# Out:
# (406, 8)
# (400, 8)

# %%
df_new.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0        8.0         307.0       130.0  3504.0          12.0
# 1  15.0        8.0         350.0       165.0  3693.0          11.5
# 2  18.0        8.0         318.0       150.0  3436.0          11.0
# 3  16.0        8.0         304.0       150.0  3433.0          12.0
# 4  17.0        8.0         302.0       140.0  3449.0          10.5
#
#    model year  origin
# 0        70.0     1.0
# 1        70.0     1.0
# 2        70.0     1.0
# 3        70.0     1.0
# 4        70.0     1.0

# %%
#seprating input and output 
df_x=df_new.drop(columns=['mpg'])
y=df_new[['mpg']]

# %%
# scaling down using standard scaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.30)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        #print('r2_score corresponding to random state: ',r_state,"is:",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print('\n\nmax r2 score corresponding to random state:',final_r_state,"is",max_r_score)
    return final_r_state

# %%
#lets use linear regression and check max  r2 score corresponding to different random states
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# max r2 score corresponding to random state: 55 is 0.8288102485783369

# %%
#lets use grid_search to find optimal value of n_neigbors for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 7}

# %%
#lets use KNN Regression and check max r2 score corresponding to different random states
knr=KNeighborsRegressor(n_neighbors=7)
r_state=maxr2_score(knr,x,y)
# Out:
# max r2 score corresponding to random state: 42 is 0.8751010592447838

# %%
#lets check the mean r2 score of both linear regression model and knn regression
from sklearn.model_selection import cross_val_score
print('Mean r2 score for linear regression : ',cross_val_score(lreg,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for Linear Regression : ',cross_val_score(lreg,x,y,cv=5,scoring='r2').std())
print('\n\n Mean r2 score for KNN Regression : ',cross_val_score(knr,x,y,cv=5,scoring='r2').mean())
print('Standard deviation in r2 score for KNN Regression : ',cross_val_score(knr,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for linear regression :  0.5050181694674721
# Standard deviation in r2 score for Linear Regression :  0.27515178234860327
#
#
#  Mean r2 score for KNN Regression :  0.638261602725277
# Standard deviation in r2 score for KNN Regression :  0.22415925117028604

# %%
#lets check Lasso regression and find best value of alpha
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={'alpha':[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.1}

# %%
#lets check max r2 score when we use lasso
lsreg=Lasso(alpha=0.01)
r_state=maxr2_score(lsreg,x,y)
# Out:
# max r2 score corresponding to random state: 55 is 0.8283019505641778

# %%
#lets use cross val score with lasso
print("Mean r2 score for lasso regression : ",cross_val_score(lsreg,x,y,cv=5,scoring='r2').mean())
print('standard deviation for lasso ragression : ',cross_val_score(lsreg,x,y,scoring='r2').std())
# Out:
# Mean r2 score for lasso regression :  0.5024459283038144
# standard deviation for lasso ragression :  0.2794676152042003

# %%
#now we will try to use gradient boosting technique
#for getting best set of parameter we will use grid search
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings('ignore')
gbr=GradientBoostingRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}

# %%
#now we will use cross val score to check the mean r2 score and standard deviation
gbr=GradientBoostingRegressor(learning_rate=0.01,n_estimators=1000)
print('Mean r2 score for gradient boosting Regrssion : ',cross_val_score(gbr,x,y,cv=5,scoring='r2').mean())
print('Standard Deviation r2 score for gradient boosting Regrssion : ',cross_val_score(gbr,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for gradient boosting Regrssion :  0.7231509593029135
# Standard Deviation r2 score for gradient boosting Regrssion :  0.15003081852917347

# %%
#Now Lets use ada boost regression algorithm
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000],'base_estimator':[lreg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 500}

# %%
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(),learning_rate=1,n_estimators=500)
print('Mean r2 score for ada boosting regression :',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').mean())
print('Standard Deviation r2 score for ada boosting regression :',cross_val_score(ada_reg,x,y,cv=5,scoring='r2').std())
# Out:
# Mean r2 score for ada boosting regression : 0.7130158064042023
# Standard Deviation r2 score for ada boosting regression : 0.15501465107566217

# %%
#lets check maximum r2_score corresponding to this
r_state=maxr2_score(ada_reg,x,y)
# Out:
# max r2 score corresponding to random state: 79 is 0.9067082192897179

# %%
# we tried all the model and till now ada boost regression is the best
#random state corresponding to highest r2_score is 79
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=79,test_size=0.30)
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(),learning_rate=1,n_estimators=500)
ada_reg.fit(x_train,y_train)
y_pred=ada_reg.predict(x_test)

# %%
#lets find the rmse and r2_score using sklearn.metrics
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is : ",np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score is : ',r2_score(y_test,y_pred))
# Out:
# RMSE is :  2.2177360324822146
# r2_score is :  0.9139459456245611

# %%
from sklearn.externals import joblib
joblib.dump(ada_reg,'mpg_model.obj')
# Out:
# ['mpg_model.obj']

# %%
model=joblib.load('mpg_model.obj')

# %%
result=pd.DataFrame(model.predict(x_test))

# %%
result.to_csv('mpgPriceprdictresults.csv')
